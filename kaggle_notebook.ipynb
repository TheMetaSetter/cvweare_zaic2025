# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
token = user_secrets.get_secret("GITHUB_PAT_CVWEARE")
GITHUB_USERNAME="TheMetaSetter"

# %%
# !git clone https://$GITHUB_USERNAME:$token@github.com/TheMetaSetter/cvweare_zaic2025.git
# Out:
# Cloning into 'cvweare_zaic2025'...
# remote: Enumerating objects: 120, done.
# remote: Counting objects: 100% (120/120), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 120 (delta 27), reused 108 (delta 21), pack-reused 0 (from 0)
# Receiving objects: 100% (120/120), 40.65 MiB | 36.87 MiB/s, done.
# Resolving deltas: 100% (27/27), done.

# %%
# !pwd
# Out:
# /kaggle/working

# %%
# !curl -LsSf https://astral.sh/uv/install.sh | sh
# Out:
# downloading uv 0.9.10 x86_64-unknown-linux-gnu
# no checksums to verify
# installing to /usr/local/bin
#   uv
#   uvx
# everything's installed!

# %%
# !uv pip install -r cvweare_zaic2025/requirements.txt
# Out:
# Using Python 3.11.13 environment at: /usr
# Resolved 94 packages in 646ms
# Prepared 4 packages in 741ms
# Uninstalled 12 packages in 112ms
# Installed 14 packages in 17.55s.0.70
#  - ipykernel==6.17.1
#  + ipykernel==7.1.0
#  - nvidia-cublas-cu12==12.5.3.2
#  + nvidia-cublas-cu12==12.4.5.8
#  - nvidia-cuda-cupti-cu12==12.5.82
#  + nvidia-cuda-cupti-cu12==12.4.127
#  - nvidia-cuda-nvrtc-cu12==12.5.82
#  + nvidia-cuda-nvrtc-cu12==12.4.127
#  - nvidia-cuda-runtime-cu12==12.5.82
#  + nvidia-cuda-runtime-cu12==12.4.127
#  - nvidia-cudnn-cu12==9.3.0.75
#  + nvidia-cudnn-cu12==9.1.0.70
#  - nvidia-cufft-cu12==11.2.3.61
#  + nvidia-cufft-cu12==11.2.1.3
#  - nvidia-curand-cu12==10.3.6.82
#  + nvidia-curand-cu12==10.3.5.147
#  - nvidia-cusolver-cu12==11.6.3.83
#  + nvidia-cusolver-cu12==11.6.1.9
#  - nvidia-cusparse-cu12==12.5.1.3
#  + nvidia-cusparse-cu12==12.3.1.170
#  - nvidia-nvjitlink-cu12==12.5.82
#  + nvidia-nvjitlink-cu12==12.4.127
#  - opencv-python==4.12.0.88
# ...

# %%
# %cd cvweare_zaic2025
# Out:
# /kaggle/working/cvweare_zaic2025

# %%
wnb_api_key = user_secrets.get_secret("wnb")

# %%
# !uv pip install wandb
# Out:
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 111ms

# %%
# !uv pip install ultralytics
# Out:
# Using Python 3.11.13 environment at: /usr
# Resolved 59 packages in 610ms
# Prepared 3 packages in 865ms
# Uninstalled 11 packages in 167ms
# Installed 13 packages in 16.78s.0.70
#  - nvidia-cublas-cu12==12.5.3.2
#  + nvidia-cublas-cu12==12.4.5.8
#  - nvidia-cuda-cupti-cu12==12.5.82
#  + nvidia-cuda-cupti-cu12==12.4.127
#  - nvidia-cuda-nvrtc-cu12==12.5.82
#  + nvidia-cuda-nvrtc-cu12==12.4.127
#  - nvidia-cuda-runtime-cu12==12.5.82
#  + nvidia-cuda-runtime-cu12==12.4.127
#  - nvidia-cudnn-cu12==9.3.0.75
#  + nvidia-cudnn-cu12==9.1.0.70
#  - nvidia-cufft-cu12==11.2.3.61
#  + nvidia-cufft-cu12==11.2.1.3
#  - nvidia-curand-cu12==10.3.6.82
#  + nvidia-curand-cu12==10.3.5.147
#  - nvidia-cusolver-cu12==11.6.3.83
#  + nvidia-cusolver-cu12==11.6.1.9
#  - nvidia-cusparse-cu12==12.5.1.3
#  + nvidia-cusparse-cu12==12.3.1.170
#  - nvidia-nvjitlink-cu12==12.5.82
#  + nvidia-nvjitlink-cu12==12.4.127
#  - opencv-python==4.12.0.88
#  + opencv-python==4.11.0.86
#  + ultralytics==8.3.229
# ...

# %%
# !wandb login --verify $wnb_api_key
# Out:
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# ...

# %%
# %cd cvweare_zaic2025
# Out:
# /kaggle/working/cvweare_zaic2025

# %%
# !ls
# Out:
# AGENTS.md     example_usage.py	       quick_test.py		todolists
# augmentation  execution_guidelines.md  README.md		train_yolo.py
# callbacks     export_to_yolo.py        requirements.txt		utils
# configs       howtopushperformance.md  run_pipeline.py		wandb
# download.py   LICENSE		       runs			yolo11n.pt
# evaluation    prepare.plan.md	       submissionguidelines.md	yolo11s.pt

# %%
# # You need to check if the path to yolo dataset inside configs is right or wrong
# !cat /kaggle/working/cvweare_zaic2025/configs/yolo_data.yaml
# Out:
# # Data definition for YOLO fine-tuning on exported drone frames.
# # Assumes export_to_yolo.py wrote images/ and labels/ inside data/yolo_dataset.
# path: data/yolo_dataset
# train: images/train
# val: images/val
# test: images/test
#
# names:
#   0: Backpack
#   1: Jacket
#   2: Laptop
#   3: Lifering
#   4: MobilePhone
#   5: Person1
#   6: WaterBottle

# %%
# !sed -i 's|path: data/yolo_dataset|path: /kaggle/input/small-object-detection-drone-vid-augmented/data/yolo_dataset|' \
#   /kaggle/working/cvweare_zaic2025/configs/yolo_data.yaml

# %%
# !cat /kaggle/working/cvweare_zaic2025/configs/yolo_data.yaml
# Out:
# # Data definition for YOLO fine-tuning on exported drone frames.
# # Assumes export_to_yolo.py wrote images/ and labels/ inside data/yolo_dataset.
# path: /kaggle/input/small-object-detection-drone-vid-augmented/data/yolo_dataset
# train: images/train
# val: images/val
# test: images/test
#
# names:
#   0: Backpack
#   1: Jacket
#   2: Laptop
#   3: Lifering
#   4: MobilePhone
#   5: Person1
#   6: WaterBottle

# %%
# !python train_yolo.py \
#     --weights yolo11n.pt \
#     --data configs/yolo_data.yaml \
#     --cfg configs/yolo_hyp_small_objects.yaml \
#     --imgsz 960 \
#     --epochs 1 \
#     --batch 32 \
#     --device 0,1 \
#     --project runs/train_smallobj_dryrun \
#     --name-suffix smoke
# Out:
# [TRAIN] yolo11n → imgsz=960, epochs=1
# Ultralytics 8.3.229 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...
